# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'employment_report.xls',
#  'sample-data.sql',
#  'Supermarket.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'supermarket_no_header.txt']

# %%
import pandas

# %%
df1 = pandas.read_csv("supermarkets.csv")
dir(df1)
# Out:
# ['Address',
#  'City',
#  'Country',
#  'Employees',
#  'ID',
#  'Name',
#  'State',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
# ...

# %%
df2 = pandas.read_excel("supermarkets.xlsx",sheet_name=0)

# %%
df3 = pandas.read_csv('supermarkets-semi-colons.txt',sep=";")
df3
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df3.mean()
# Out:
# ID            3.5
# Employees    15.0
# dtype: float64

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'employment_report.xls',
#  'sample-data.sql',
#  'Supermarket.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'supermarket_no_header.txt']

# %%
df4 = pandas.read_csv('supermarket_no_header.txt',header = None)
df4
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df4.columns = ['ID','Address','City','State','Country','Name','Number of Employees']

# %%
df4.set_index('ID')
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
my_supermarkets = df4.set_index('Name')

# %%
my_supermarkets
# Out:
#              ID          Address           City             State Country  \
# Name
#  Madeira      1     3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   2   735 Dolores St  San Francisco          CA 94119     USA
# Super River   3      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop    4     3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       5  1056 Sanchez St  San Francisco        California     USA
# Richvalley    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#              Number of Employees
# Name
#  Madeira                       8
# Bready Shop                   15
# Super River                   25
# Ben's Shop                    10
# Sanchez                       12
# Richvalley                    20

# %%
df4.set_index('ID',inplace=True,drop=False)

# %%
df4.set_index('Name', inplace=True, drop=False)
df4
# Out:
#              ID          Address           City             State Country  \
# Name
#  Madeira      1     3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   2   735 Dolores St  San Francisco          CA 94119     USA
# Super River   3      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop    4     3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       5  1056 Sanchez St  San Francisco        California     USA
# Richvalley    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Number of Employees
# Name
#  Madeira         Madeira                    8
# Bready Shop  Bready Shop                   15
# Super River  Super River                   25
# Ben's Shop    Ben's Shop                   10
# Sanchez          Sanchez                   12
# Richvalley    Richvalley                   20

# %%
df4['Number of Employees'].count()
# Out:
# 6

# %%
df4['Number of Employees']
# Out:
# Name
#  Madeira        8
# Bready Shop    15
# Super River    25
# Ben's Shop     10
# Sanchez        12
# Richvalley     20
# Name: Number of Employees, dtype: int64

# %%
df4
# Out:
#              ID          Address           City             State Country  \
# Name
#  Madeira      1     3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   2   735 Dolores St  San Francisco          CA 94119     USA
# Super River   3      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop    4     3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       5  1056 Sanchez St  San Francisco        California     USA
# Richvalley    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Number of Employees
# Name
#  Madeira         Madeira                    8
# Bready Shop  Bready Shop                   15
# Super River  Super River                   25
# Ben's Shop    Ben's Shop                   10
# Sanchez          Sanchez                   12
# Richvalley    Richvalley                   20

# %%
# slicing
df4.loc[:'Super River','Address':'Country']
# Out:
#                     Address           City             State Country
# Name
#  Madeira       3666 21st St  San Francisco          CA 94114     USA
# Bready Shop  735 Dolores St  San Francisco          CA 94119     USA
# Super River     332 Hill St  San Francisco  California 94114     USA

# %%
emp = list(df4['Number of Employees'])

# %%
sum(df4['ID'])
# Out:
# 21

# %%
emp
# Out:
# [8, 15, 25, 10, 12, 20]

# %%
df4
# Out:
#              ID          Address           City             State Country  \
# Name
#  Madeira      1     3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   2   735 Dolores St  San Francisco          CA 94119     USA
# Super River   3      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop    4     3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       5  1056 Sanchez St  San Francisco        California     USA
# Richvalley    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Number of Employees
# Name
#  Madeira         Madeira                    8
# Bready Shop  Bready Shop                   15
# Super River  Super River                   25
# Ben's Shop    Ben's Shop                   10
# Sanchez          Sanchez                   12
# Richvalley    Richvalley                   20

# %%
df4.loc["Ben's Shop","Number of Employees"]
# Out:
# 10

# %%
df4
# Out:
#              ID          Address           City             State Country  \
# Name
#  Madeira      1     3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   2   735 Dolores St  San Francisco          CA 94119     USA
# Super River   3      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop    4     3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       5  1056 Sanchez St  San Francisco        California     USA
# Richvalley    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Number of Employees
# Name
#  Madeira         Madeira                    8
# Bready Shop  Bready Shop                   15
# Super River  Super River                   25
# Ben's Shop    Ben's Shop                   10
# Sanchez          Sanchez                   12
# Richvalley    Richvalley                   20

# %%
# df4.iloc[0:2,0:3]
df4.iloc[5:4,1:4]
# Out:
# Empty DataFrame
# Columns: [Address, City, State]
# Index: []

# %%
df4
# Out:
#              ID          Address           City             State Country  \
# Name
#  Madeira      1     3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   2   735 Dolores St  San Francisco          CA 94119     USA
# Super River   3      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop    4     3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       5  1056 Sanchez St  San Francisco        California     USA
# Richvalley    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Number of Employees
# Name
#  Madeira         Madeira                    8
# Bready Shop  Bready Shop                   15
# Super River  Super River                   25
# Ben's Shop    Ben's Shop                   10
# Sanchez          Sanchez                   12
# Richvalley    Richvalley                   20

# %%
df4.drop("Country",1)
# Out:
#              ID          Address           City             State  \
# Name
#  Madeira      1     3666 21st St  San Francisco          CA 94114
# Bready Shop   2   735 Dolores St  San Francisco          CA 94119
# Super River   3      332 Hill St  San Francisco  California 94114
# Ben's Shop    4     3995 23rd St  San Francisco          CA 94114
# Sanchez       5  1056 Sanchez St  San Francisco        California
# Richvalley    6  551 Alvarado St  San Francisco          CA 94114
#
#                     Name  Number of Employees
# Name
#  Madeira         Madeira                    8
# Bready Shop  Bready Shop                   15
# Super River  Super River                   25
# Ben's Shop    Ben's Shop                   10
# Sanchez          Sanchez                   12
# Richvalley    Richvalley                   20

# %%
df4_updated = df4.drop("Country",1)

# %%
df4.ix[2,4]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19252/3229624033.py in <module>
# ----> 1 df4.ix[2,4]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %%
df4
# Out:
#              ID          Address           City             State Country  \
# Name
#  Madeira      1     3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   2   735 Dolores St  San Francisco          CA 94119     USA
# Super River   3      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop    4     3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       5  1056 Sanchez St  San Francisco        California     USA
# Richvalley    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Number of Employees
# Name
#  Madeira         Madeira                    8
# Bready Shop  Bready Shop                   15
# Super River  Super River                   25
# Ben's Shop    Ben's Shop                   10
# Sanchez          Sanchez                   12
# Richvalley    Richvalley                   20

# %%
df4.drop(df4.index[0:3])

# %%
df4.index

# %%
df4.columns
# Out:
# Index(['ID', 'Address', 'City', 'State', 'Country', 'Name',
#        'Number of Employees', 'Continent'],
#       dtype='object')

# %%
df4.drop(df4.columns[2:3],1)
# Out:
#              ID          Address             State Country         Name  \
# Name
#  Madeira      1     3666 21st St          CA 94114     USA      Madeira
# Bready Shop   2   735 Dolores St          CA 94119     USA  Bready Shop
# Super River   3      332 Hill St  California 94114     USA  Super River
# Ben's Shop    4     3995 23rd St          CA 94114     USA   Ben's Shop
# Sanchez       5  1056 Sanchez St        California     USA      Sanchez
# Richvalley    6  551 Alvarado St          CA 94114     USA   Richvalley
#
#              Number of Employees      Continent
# Name
#  Madeira                       8  North America
# Bready Shop                   15  North America
# Super River                   25  North America
# Ben's Shop                    10  North America
# Sanchez                       12  North America
# Richvalley                    20  North America

# %%
df4
# Out:
#              ID          Address           City             State Country  \
# Name
#  Madeira      1     3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   2   735 Dolores St  San Francisco          CA 94119     USA
# Super River   3      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop    4     3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       5  1056 Sanchez St  San Francisco        California     USA
# Richvalley    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Number of Employees      Continent
# Name
#  Madeira         Madeira                    8  North America
# Bready Shop  Bready Shop                   15  North America
# Super River  Super River                   25  North America
# Ben's Shop    Ben's Shop                   10  North America
# Sanchez          Sanchez                   12  North America
# Richvalley    Richvalley                   20  North America

# %%
df4.drop(df4.columns[1:4],1)
# Out:
#              ID Country         Name  Number of Employees      Continent
# Name
#  Madeira      1     USA      Madeira                    8  North America
# Bready Shop   2     USA  Bready Shop                   15  North America
# Super River   3     USA  Super River                   25  North America
# Ben's Shop    4     USA   Ben's Shop                   10  North America
# Sanchez       5     USA      Sanchez                   12  North America
# Richvalley    6     USA   Richvalley                   20  North America

# %%
df4

# %%
df4['Continent'] = "North America"

# %%
df4= df4.drop("Continent",1)
df4

# %%
cont = input("Enter name:")

# %%
df4['Continent'] = df4.shape[0]*['North America']

# %%
df4

# %%
df4['Full Address'] = df4['Address']+', '+df4['City']+', '+df4['State']

# %%
df4

# %%
df4 = df4.drop("Full Address",1)

# %%
df4_t = df4.T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19252/3413102577.py in <module>
# ----> 1 df4_t = df4.T
#
# NameError: name 'df4' is not defined

# %%
df4_t

# %%
df4_t["xioc"] = [7,"Section-1, Block-B, Road #2, House #50","Mirpur","Dhaka -1216","BD","Maruf's Garden",53,"Aisa"]

# %%
df4 = df4_t.T
df4

# %%
df4 = df4.drop("xioc",0)

# %%
df4 = df4.drop("Name",1)

# %%
df4

# %%
df4_t = df4.T

# %%
df4_t

# %%
df4_t["Maruf's Garden"] =["My Name",7,"Sec-1,Mirpur","Dhaka-1216","Dhaka","BGD","Aisa"]

# %%
df4

# %%
df4_t.drop("Maruf's Garden",0)

# %%
df4_t["Maruf"] =[7,"Section-1 ,Mirpur","Dhaka 1216","Dhaka","BGD",52,"Asia"]

# %%
df4_t = df4_t.drop("Maruf's Garden",1)
df4_t

# %%
df4 = df4_t.T

# %%
df4
# Out:
#              ID          Address           City             State Country  \
# Name
#  Madeira      1     3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   2   735 Dolores St  San Francisco          CA 94119     USA
# Super River   3      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop    4     3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       5  1056 Sanchez St  San Francisco        California     USA
# Richvalley    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Number of Employees
# Name
#  Madeira         Madeira                    8
# Bready Shop  Bready Shop                   15
# Super River  Super River                   25
# Ben's Shop    Ben's Shop                   10
# Sanchez          Sanchez                   12
# Richvalley    Richvalley                   20

# %%
location = df4['Address']+', '+df4['City']+', '+df4['State']+', '+df4['Country']

# %%
location
# Out:
# Name
#  Madeira              3666 21st St, San Francisco, CA 94114, USA
# Bready Shop         735 Dolores St, San Francisco, CA 94119, USA
# Super River    332 Hill St, San Francisco, California 94114, USA
# Ben's Shop            3995 23rd St, San Francisco, CA 94114, USA
# Sanchez          1056 Sanchez St, San Francisco, California, USA
# Richvalley         551 Alvarado St, San Francisco, CA 94114, USA
# dtype: object

# %%
addr = list(location)

# %%
addr
# Out:
# ['3666 21st St, San Francisco, CA 94114, USA',
#  '735 Dolores St, San Francisco, CA 94119, USA',
#  '332 Hill St, San Francisco, California 94114, USA',
#  '3995 23rd St, San Francisco, CA 94114, USA',
#  '1056 Sanchez St, San Francisco, California, USA',
#  '551 Alvarado St, San Francisco, CA 94114, USA']

# %%
import geopy
dir(geopy)
# Out:
# ['AlgoliaPlaces',
#  'ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'BaiduV3',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'Geocodio',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'HereV7',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'MapQuest',
#  'MapTiler',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'What3WordsV3',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '__version_info__',
#  'adapters',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'get_version',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
from geopy.geocoder import ArcGIS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15348/2165272974.py in <module>
# ----> 1 from geopy.geocoder import ArcGIS
#
# ModuleNotFoundError: No module named 'geopy.geocoder'

# %%
from geopy.geocoders import ArcGIS

# %%
dir(ArcGIS)
# Out:
# ['_TOKEN_EXPIRED',
#  '__aenter__',
#  '__aexit__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_adapter_error_handler',
#  '_authenticated_call_geocoder',
#  '_call_geocoder',
#  '_coerce_point_to_string',
#  '_format_bounding_box',
#  '_geocoder_exception_handler',
#  '_parse_geocode',
#  '_parse_reverse',
#  '_refresh_authentication_token',
#  'auth_path',
#  'geocode',
#  'geocode_path',
#  'reverse',
#  'reverse_path']

# %%
ArcGIS.geocode('Section-1,Block-B, Road -2, House -50, Mirpur-1,Dhaka,Bangladesh')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15348/1550994683.py in <module>
# ----> 1 ArcGIS.geocode('Section-1,Block-B, Road -2, House -50, Mirpur-1,Dhaka,Bangladesh')
#
# TypeError: geocode() missing 1 required positional argument: 'query'

# %%
var = ArcGIS()

# %%
var.geocode("Section-1,Block-B, Road -2,Mirpur,Dhaka-1216")
# Out:
# Location(Section 1 Block B, Dhaka, (23.80502000000007, 90.34900000000005, 0.0))

# %%
addr
# Out:
# ['3666 21st St, San Francisco, CA 94114, USA',
#  '735 Dolores St, San Francisco, CA 94119, USA',
#  '332 Hill St, San Francisco, California 94114, USA',
#  '3995 23rd St, San Francisco, CA 94114, USA',
#  '1056 Sanchez St, San Francisco, California, USA',
#  '551 Alvarado St, San Francisco, CA 94114, USA']

# %%
df4
# Out:
#              ID          Address           City             State Country  \
# Name
#  Madeira      1     3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   2   735 Dolores St  San Francisco          CA 94119     USA
# Super River   3      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop    4     3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       5  1056 Sanchez St  San Francisco        California     USA
# Richvalley    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Number of Employees
# Name
#  Madeira         Madeira                    8
# Bready Shop  Bready Shop                   15
# Super River  Super River                   25
# Ben's Shop    Ben's Shop                   10
# Sanchez          Sanchez                   12
# Richvalley    Richvalley                   20

# %%
df4['Latitude, Longitude'] = var.geocode(df4['Address']+', '+df4['City']+', '+df4['State']
+', '+df4['Country']).latitude, var.geocode(df4['Address']+', '+df4['City']+', '+df4['State']
+', '+df4['Country']).longitude
# Out:
# ---------------------------------------------------------------------------
# GeocoderServiceError                      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15348/3434943481.py in <module>
# ----> 1 df4['Latitude, Longitude'] = var.geocode(df4['Address']+', '+df4['City']+', '+df4['State']
#       2 +', '+df4['Country']).latitude, var.geocode(df4['Address']+', '+df4['City']+', '+df4['State']
#       3 +', '+df4['Country']).longitude
#
# ~\anaconda3\lib\site-packages\geopy\geocoders\arcgis.py in geocode(self, query, exactly_one, timeout, out_fields)
#     171         logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     172         callback = partial(self._parse_geocode, exactly_one=exactly_one)
# --> 173         return self._authenticated_call_geocoder(url, callback, timeout=timeout)
#     174
#     175     def _parse_geocode(self, response, exactly_one):
#
# ...

# %%
df4
# Out:
#              ID          Address           City             State Country  \
# Name
#  Madeira      1     3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   2   735 Dolores St  San Francisco          CA 94119     USA
# Super River   3      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop    4     3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       5  1056 Sanchez St  San Francisco        California     USA
# Richvalley    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Number of Employees
# Name
#  Madeira         Madeira                    8
# Bready Shop  Bready Shop                   15
# Super River  Super River                   25
# Ben's Shop    Ben's Shop                   10
# Sanchez          Sanchez                   12
# Richvalley    Richvalley                   20

# %%
var.geocode(df4['Address']+', '+df4['City']+', '+df4['Country'])
# Out:
# ---------------------------------------------------------------------------
# GeocoderServiceError                      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15348/4050241814.py in <module>
# ----> 1 var.geocode(df4['Address']+', '+df4['City']+', '+df4['Country'])
#
# ~\anaconda3\lib\site-packages\geopy\geocoders\arcgis.py in geocode(self, query, exactly_one, timeout, out_fields)
#     171         logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     172         callback = partial(self._parse_geocode, exactly_one=exactly_one)
# --> 173         return self._authenticated_call_geocoder(url, callback, timeout=timeout)
#     174
#     175     def _parse_geocode(self, response, exactly_one):
#
# ~\anaconda3\lib\site-packages\geopy\geocoders\arcgis.py in _authenticated_call_geocoder(self, url, parse_callback, timeout)
#     258     ):
#     259         if not self.username:
# ...

# %%
addr
# Out:
# ['3666 21st St, San Francisco, CA 94114, USA',
#  '735 Dolores St, San Francisco, CA 94119, USA',
#  '332 Hill St, San Francisco, California 94114, USA',
#  '3995 23rd St, San Francisco, CA 94114, USA',
#  '1056 Sanchez St, San Francisco, California, USA',
#  '551 Alvarado St, San Francisco, CA 94114, USA']

# %%
geoloc={}
loc = []
for l in addr:
    latitude = var.geocode(l).latitude
    longitude = var.geocode(l).longitude
    geoloc[l] = [latitude, longitude]
    loc.append([latitude, longitude])

# %%
geoloc
# Out:
# {'3666 21st St, San Francisco, CA 94114, USA': [37.756632001957215,
#   -122.42941101194798],
#  '735 Dolores St, San Francisco, CA 94119, USA': [37.757828979640195,
#   -122.4253730300932],
#  '332 Hill St, San Francisco, California 94114, USA': [37.75584498315857,
#   -122.42881296315642],
#  '3995 23rd St, San Francisco, CA 94114, USA': [37.75292099814533,
#   -122.43170295955227],
#  '1056 Sanchez St, San Francisco, California, USA': [37.75213200959942,
#   -122.43000595943536],
#  '551 Alvarado St, San Francisco, CA 94114, USA': [37.753581995029734,
#   -122.43323399798629]}

# %%
loc
# Out:
# [[37.756632001957215, -122.42941101194798],
#  [37.757828979640195, -122.4253730300932],
#  [37.75584498315857, -122.42881296315642],
#  [37.75292099814533, -122.43170295955227],
#  [37.75213200959942, -122.43000595943536],
#  [37.753581995029734, -122.43323399798629]]

# %%
df4
# Out:
#              ID          Address           City             State Country  \
# Name
#  Madeira      1     3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   2   735 Dolores St  San Francisco          CA 94119     USA
# Super River   3      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop    4     3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       5  1056 Sanchez St  San Francisco        California     USA
# Richvalley    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Number of Employees
# Name
#  Madeira         Madeira                    8
# Bready Shop  Bready Shop                   15
# Super River  Super River                   25
# Ben's Shop    Ben's Shop                   10
# Sanchez          Sanchez                   12
# Richvalley    Richvalley                   20

# %%
df4['Latitude, Longitude']=var.geocode(df4['Address']+','+df4['City']+','+df4['State']+df4['Country']).latitude,
var.geocode(df4['Address']+','+df4['City']+','+df4['State']+df4['Country']).longitude
# Out:
# ---------------------------------------------------------------------------
# GeocoderServiceError                      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15348/1807940959.py in <module>
# ----> 1 df4['Latitude, Longitude']=var.geocode(df4['Address']+','+df4['City']+','+df4['State']+df4['Country']).latitude,
#       2 var.geocode(df4['Address']+','+df4['City']+','+df4['State']+df4['Country']).longitude
#       3
#       4
#       5
#
# ~\anaconda3\lib\site-packages\geopy\geocoders\arcgis.py in geocode(self, query, exactly_one, timeout, out_fields)
#     171         logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     172         callback = partial(self._parse_geocode, exactly_one=exactly_one)
# --> 173         return self._authenticated_call_geocoder(url, callback, timeout=timeout)
#     174
#     175     def _parse_geocode(self, response, exactly_one):
#
# ...

# %%
df = pandas.read_csv('supermarkets.csv')

# %%
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df['Full Address'] = df['Address']+', '+df['City']+', '+df['State']+', '+df['Country']

# %%
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                       Full Address
# 0          8         3666 21st St, San Francisco, CA 94114, USA
# 1         15       735 Dolores St, San Francisco, CA 94119, USA
# 2         25  332 Hill St, San Francisco, California 94114, USA
# 3         10         3995 23rd St, San Francisco, CA 94114, USA
# 4         12    1056 Sanchez St, San Francisco, California, USA
# ...

# %%
df['Latitude, Longitude'] = var.geocode(df['Full Address']).latitude[5], var.geocode(df['Full Address']).longitude[5]
# Out:
# ---------------------------------------------------------------------------
# GeocoderServiceError                      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15348/3598287038.py in <module>
# ----> 1 df['Latitude, Longitude'] = var.geocode(df['Full Address']).latitude[5], var.geocode(df['Full Address']).longitude[5]
#
# ~\anaconda3\lib\site-packages\geopy\geocoders\arcgis.py in geocode(self, query, exactly_one, timeout, out_fields)
#     171         logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     172         callback = partial(self._parse_geocode, exactly_one=exactly_one)
# --> 173         return self._authenticated_call_geocoder(url, callback, timeout=timeout)
#     174
#     175     def _parse_geocode(self, response, exactly_one):
#
# ~\anaconda3\lib\site-packages\geopy\geocoders\arcgis.py in _authenticated_call_geocoder(self, url, parse_callback, timeout)
#     258     ):
#     259         if not self.username:
# ...

# %%
df["Coordinates"] = df["Full Address"].apply(var.geocode())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15348/3554330868.py in <module>
# ----> 1 df["Coordinates"] = df["Full Address"].apply(var.geocode())
#
# TypeError: geocode() missing 1 required positional argument: 'query'

# %%
len(df)
# Out:
# 6

# %%
for x in range(len(df)):
    df['Latitude'] = df.Coordinates[x].latitude
    df['Longitude'] = df.Coordinates[x].longitude

# %%
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                       Full Address  \
# 0          8         3666 21st St, San Francisco, CA 94114, USA
# 1         15       735 Dolores St, San Francisco, CA 94119, USA
# 2         25  332 Hill St, San Francisco, California 94114, USA
# 3         10         3995 23rd St, San Francisco, CA 94114, USA
# 4         12    1056 Sanchez St, San Francisco, California, USA
# ...

# %%
df.drop("Coordinates",1)
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                       Full Address   Latitude  \
# 0          8         3666 21st St, San Francisco, CA 94114, USA  37.753582
# 1         15       735 Dolores St, San Francisco, CA 94119, USA  37.753582
# 2         25  332 Hill St, San Francisco, California 94114, USA  37.753582
# 3         10         3995 23rd St, San Francisco, CA 94114, USA  37.753582
# ...
